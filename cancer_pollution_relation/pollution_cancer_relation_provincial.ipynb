# %%
# Livello provinciale (tutte le province italiane)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

inqui = pd.read_csv('../csv/tumori.csv', encoding='utf-8', sep=',')
inqui_s = inqui.sort_values(by=["Pm10"], ascending=True)
inqui_s.plot.scatter(x='Value', y='Pm10')

plt.show()

# Questo dimostra che non c'è relazione tra livello alto di polveri
# sottili nell'aria e mortalità per tumori (vie respiratorie).
# Perlomeno non c'è una "RILEVANTE" relazione tra polveri e tumori.
